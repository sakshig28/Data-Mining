# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Import libraries

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt     # same as 'import matplotlib.pyplot as plt'
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### Review raw data

# %%
! ls -l 'data/insurance_rates.csv'
# Out:
# -rw-r--r--@ 1 vj  staff  48679 Feb  7 09:47 data/insurance_rates.csv

# %%
! wc -l 'data/insurance_rates.csv'
# Out:
#     1338 data/insurance_rates.csv

# %%
! head 'data/insurance_rates.csv'
# Out:
# age,gender,smoker,bmi,children,region,charges
# 19,0,1,27.9,0,southwest,16884.924
# 18,1,0,33.77,1,southeast,1725.5523
# 28,1,0,33,3,southeast,4449.462
# 33,1,0,22.705,0,northwest,21984.47061
# 32,1,0,28.88,0,northwest,3866.8552
# 31,0,0,25.74,0,southeast,3756.6216
# 46,0,0,33.44,1,southeast,8240.5896
# 37,0,0,27.74,3,northwest,7281.5056
# 37,1,0,29.83,2,northeast,6406.4107

# %% [markdown]
# ### Load data
# Columns
# * age: age of primary beneficiary
# * sex: female=0, male=1
# * bmi: body mass index
# * children: # of children covered by health insurance
# * smoker: yes=1, no=0
# * region: the beneficiary's residential area in the US, northeast, southeast, southwest, northwest.
# * charges: individual medical costs billed by health insurance

# %%
# Read data file (insurance_rates.csv) into a dataframe
#  Default field separator is ','
df = pd.read_csv('data/insurance_rates.csv', sep=',')

# %%
# Display shape of dataframe
df.shape
# Out:
# (1338, 7)

# %%
# Display info about dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   gender    1338 non-null   int64
#  2   smoker    1338 non-null   int64
#  3   bmi       1338 non-null   float64
#  4   children  1338 non-null   int64
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 73.3+ KB

# %%
# Display columns
df.columns
# Out:
# Index(['age', 'gender', 'smoker', 'bmi', 'children', 'region', 'charges'], dtype='object')

# %%
# Display column datatypes
df.dtypes
# Out:
# age           int64
# gender        int64
# smoker        int64
# bmi         float64
# children      int64
# region       object
# charges     float64
# dtype: object

# %%
# Display first few rows
df.head()
# Out:
#    age  gender  smoker     bmi  children     region      charges
# 0   19       0       1  27.900         0  southwest  16884.92400
# 1   18       1       0  33.770         1  southeast   1725.55230
# 2   28       1       0  33.000         3  southeast   4449.46200
# 3   33       1       0  22.705         0  northwest  21984.47061
# 4   32       1       0  28.880         0  northwest   3866.85520

# %%
# Display last few rows
df.tail()
# Out:
#       age  gender  smoker    bmi  children     region     charges
# 1333   50       1       0  30.97         3  northwest  10600.5483
# 1334   18       0       0  31.92         0  northeast   2205.9808
# 1335   18       0       0  36.85         0  southeast   1629.8335
# 1336   21       0       0  25.80         0  southwest   2007.9450
# 1337   61       0       1  29.07         0  northwest  29141.3603

# %%
# Display random sample of N rows
df.sample(10)
# Out:
#       age  gender  smoker     bmi  children     region      charges
# 756    39       0       0  22.800         3  northeast   7985.81500
# 151    48       1       0  29.700         0  southeast   7789.63500
# 1081   32       1       0  27.835         1  northwest   4454.40265
# 666    49       1       0  28.700         1  southwest   8703.45600
# 1142   52       0       0  24.860         0  southeast  27117.99378
# 346    33       1       0  35.750         2  southeast   4889.99950
# 72     53       0       0  28.100         3  southwest  11741.72600
# 415    43       0       0  35.640         1  southeast   7345.72660
# 518    35       0       0  31.000         1  southwest   5240.76500
# 51     21       0       0  33.630         2  northwest   3579.82870

# %%
# Count # of duplicated rows
df.duplicated().sum()
# Out:
# 1

# %%
# Display duplicated rows
df[df.duplicated(keep=False)]
# Out:
#      age  gender  smoker    bmi  children     region    charges
# 195   19       1       0  30.59         0  northwest  1639.5631
# 581   19       1       0  30.59         0  northwest  1639.5631

# %%
# Generate summary statistics for numeric columns
df.describe()
# Out:
#                age       gender       smoker          bmi     children  \
# count  1338.000000  1338.000000  1338.000000  1338.000000  1338.000000
# mean     39.207025     0.505232     0.204783    30.663397     1.094918
# std      14.049960     0.500160     0.403694     6.098187     1.205493
# min      18.000000     0.000000     0.000000    15.960000     0.000000
# 25%      27.000000     0.000000     0.000000    26.296250     0.000000
# 50%      39.000000     1.000000     0.000000    30.400000     1.000000
# 75%      51.000000     1.000000     0.000000    34.693750     2.000000
# max      64.000000     1.000000     1.000000    53.130000     5.000000
#
#             charges
# count   1338.000000
# mean   13270.422265
# std    12110.011237
# min     1121.873900
# 25%     4740.287150
# 50%     9382.033000
# 75%    16639.912515
# max    63770.428010

# %%
# Generate summary statistics for numeric columns in transposed format
df.describe().T
# Out:
#            count          mean           std        min         25%       50%  \
# age       1338.0     39.207025     14.049960    18.0000    27.00000    39.000
# gender    1338.0      0.505232      0.500160     0.0000     0.00000     1.000
# smoker    1338.0      0.204783      0.403694     0.0000     0.00000     0.000
# bmi       1338.0     30.663397      6.098187    15.9600    26.29625    30.400
# children  1338.0      1.094918      1.205493     0.0000     0.00000     1.000
# charges   1338.0  13270.422265  12110.011237  1121.8739  4740.28715  9382.033
#
#                    75%          max
# age          51.000000     64.00000
# gender        1.000000      1.00000
# smoker        0.000000      1.00000
# bmi          34.693750     53.13000
# children      2.000000      5.00000
# charges   16639.912515  63770.42801

# %% [markdown]
# ### Visualize data using Pandas

# %%
# Plot charges vs age (using red points)
df.plot(x='charges', y='age', style='r.')
# Out:
# <Axes: xlabel='charges'>

# %%
# Plot charges vs age (using green circles)
df.plot(x='charges', y='bmi', style='go')
# Out:
# <Axes: xlabel='charges'>

# %%
# Plot charges vs age (using blue pixels)
df.plot(x='charges', y='bmi', style='b,')
# Out:
# <Axes: xlabel='charges'>

# %%
# Display average charges by region
df.groupby('region')['charges'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='region'>

# %% [markdown]
# ### Visualize data using Matplotlib

# %%
# Plot variable charges vs age
plt.figure(figsize=(10, 4))
plt.plot(df['charges'], df['age'], 'g.')     # green points
plt.title('charges vs age')
plt.xlabel('charges')
plt.ylabel('age')
plt.show()

# %%
# Plot variable charges vs bmi
plt.figure(figsize=(12, 6))
plt.plot(df['charges'], df['bmi'], 'bo')     # blue circles
plt.title('charges vs bmi')
plt.xlabel('charges')
plt.ylabel('bmi')
plt.show()

# %%
# Plot variable charges vs bmi using the default color map 'viridis'
plt.scatter(df['charges'], df['bmi'], c=df['bmi'])
plt.colorbar()
plt.title('charges vs bmi')
plt.xlabel('charges')
plt.ylabel('bmi')
plt.show()

# %%
# Plot variable charges vs bmi using a diverging color map
plt.scatter(df['charges'], df['bmi'], c=df['bmi'], cmap='Spectral')
plt.colorbar()
plt.title('charges vs bmi')
plt.xlabel('charges')
plt.ylabel('bmi')
plt.show()

# %%
# Plot variable charges vs bmi in a wider format using a sequential color map of blues
plt.figure(figsize=(16, 8), dpi=80)
plt.scatter(df['charges'], df['bmi'], c=df['bmi'], cmap='Blues')
plt.colorbar()
plt.title('charges vs bmi')
plt.xlabel('charges')
plt.ylabel('bmi')
plt.show()

# %% [markdown]
# ### Visualize data using Seaborn

# %%
sns.set(style="darkgrid")
sns.histplot(data=df, x='charges')
plt.show()

# %%
sns.set(style="whitegrid")
sns.histplot(data=df, x='bmi')
plt.show()

# %%
# A kdeplot is a Kernel Distribution Estimation Plot which depicts the probability density function
#  of the continuous data variable
sns.set(style="darkgrid")
sns.histplot(data=df, x='bmi', kde=True)
plt.show()

# %%
sns.set(style="whitegrid")
sns.histplot(data=df, x='age', bins=10)
plt.show()

# %% [markdown]
# ### Display the correlation matrix showing the correlations of the features with each other

# %%
plt.figure(figsize = (10,4))
# Calculate the linear relationships between the variables
correlation_matrix = df.corr(numeric_only=True).round(2)
sns.heatmap(correlation_matrix, annot = True)
# Out:
# <Axes: >

# %%
plt.figure(figsize = (10,4))
# Calculate the linear relationships between the variables
correlation_matrix = df.corr(numeric_only=True).round(2)
# Display only relevant portion of matrix
mask = np.zeros_like(correlation_matrix, dtype=bool)
mask[np.triu_indices_from(mask)] = True          # numpy triu returns the upper triangle of an array
sns.heatmap(correlation_matrix, annot = True, mask=mask)
# Out:
# <Axes: >

# %% [markdown]
# ### Load another dataset

# %%
df2 = pd.read_csv("data/Aus_weather.csv", index_col=0)

# %%
df2.shape
# Out:
# (145460, 22)

# %%
df2.head(15)
# Out:
#            Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# Date
# 2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# 2008-12-06   Albury     14.6     29.7       0.2          NaN       NaN
# 2008-12-07   Albury     14.3     25.0       0.0          NaN       NaN
# 2008-12-08   Albury      7.7     26.7       0.0          NaN       NaN
# 2008-12-09   Albury      9.7     31.9       0.0          NaN       NaN
# 2008-12-10   Albury     13.1     30.1       1.4          NaN       NaN
# 2008-12-11   Albury     13.4     30.4       0.0          NaN       NaN
# 2008-12-12   Albury     15.9     21.7       2.2          NaN       NaN
# 2008-12-13   Albury     15.9     18.6      15.6          NaN       NaN
# 2008-12-14   Albury     12.6     21.0       3.6          NaN       NaN
# 2008-12-15   Albury      8.4     24.6       0.0          NaN       NaN
#
#            WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  \
# Date                                                         ...
# 2008-12-01           W           44.0          W        WNW  ...         71.0
# 2008-12-02         WNW           44.0        NNW        WSW  ...         44.0
# 2008-12-03         WSW           46.0          W        WSW  ...         38.0
# 2008-12-04          NE           24.0         SE          E  ...         45.0
# 2008-12-05           W           41.0        ENE         NW  ...         82.0
# 2008-12-06         WNW           56.0          W          W  ...         55.0
# 2008-12-07           W           50.0         SW          W  ...         49.0
# 2008-12-08           W           35.0        SSE          W  ...         48.0
# 2008-12-09         NNW           80.0         SE         NW  ...         42.0
# 2008-12-10           W           28.0          S        SSE  ...         58.0
# 2008-12-11           N           30.0        SSE        ESE  ...         48.0
# 2008-12-12         NNE           31.0         NE        ENE  ...         89.0
# 2008-12-13           W           61.0        NNW        NNW  ...         76.0
# 2008-12-14          SW           44.0          W        SSW  ...         65.0
# 2008-12-15         NaN            NaN          S        WNW  ...         57.0
#
#             Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  \
# Date
# 2008-12-01         22.0       1007.7       1007.1       8.0       NaN
# 2008-12-02         25.0       1010.6       1007.8       NaN       NaN
# 2008-12-03         30.0       1007.6       1008.7       NaN       2.0
# 2008-12-04         16.0       1017.6       1012.8       NaN       NaN
# 2008-12-05         33.0       1010.8       1006.0       7.0       8.0
# 2008-12-06         23.0       1009.2       1005.4       NaN       NaN
# 2008-12-07         19.0       1009.6       1008.2       1.0       NaN
# 2008-12-08         19.0       1013.4       1010.1       NaN       NaN
# 2008-12-09          9.0       1008.9       1003.6       NaN       NaN
# 2008-12-10         27.0       1007.0       1005.7       NaN       NaN
# 2008-12-11         22.0       1011.8       1008.7       NaN       NaN
# 2008-12-12         91.0       1010.5       1004.2       8.0       8.0
# 2008-12-13         93.0        994.3        993.0       8.0       8.0
# 2008-12-14         43.0       1001.2       1001.8       NaN       7.0
# 2008-12-15         32.0       1009.7       1008.7       NaN       NaN
#
#             Temp9am  Temp3pm  RainToday  RainTomorrow
# Date
# 2008-12-01     16.9     21.8         No            No
# 2008-12-02     17.2     24.3         No            No
# 2008-12-03     21.0     23.2         No            No
# 2008-12-04     18.1     26.5         No            No
# 2008-12-05     17.8     29.7         No            No
# 2008-12-06     20.6     28.9         No            No
# 2008-12-07     18.1     24.6         No            No
# 2008-12-08     16.3     25.5         No            No
# 2008-12-09     18.3     30.2         No           Yes
# 2008-12-10     20.1     28.2        Yes            No
# 2008-12-11     20.4     28.8         No           Yes
# 2008-12-12     15.9     17.0        Yes           Yes
# 2008-12-13     17.4     15.8        Yes           Yes
# 2008-12-14     15.8     19.8        Yes            No
# 2008-12-15     15.9     23.5         No           NaN
#
# [15 rows x 22 columns]

# %%
# Display all columns
pd.set_option('display.max_columns', None)

# %%
df2.head(15)
# Out:
#            Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# Date
# 2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# 2008-12-06   Albury     14.6     29.7       0.2          NaN       NaN
# 2008-12-07   Albury     14.3     25.0       0.0          NaN       NaN
# 2008-12-08   Albury      7.7     26.7       0.0          NaN       NaN
# 2008-12-09   Albury      9.7     31.9       0.0          NaN       NaN
# 2008-12-10   Albury     13.1     30.1       1.4          NaN       NaN
# 2008-12-11   Albury     13.4     30.4       0.0          NaN       NaN
# 2008-12-12   Albury     15.9     21.7       2.2          NaN       NaN
# 2008-12-13   Albury     15.9     18.6      15.6          NaN       NaN
# 2008-12-14   Albury     12.6     21.0       3.6          NaN       NaN
# 2008-12-15   Albury      8.4     24.6       0.0          NaN       NaN
#
#            WindGustDir  WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  \
# Date
# 2008-12-01           W           44.0          W        WNW          20.0
# 2008-12-02         WNW           44.0        NNW        WSW           4.0
# 2008-12-03         WSW           46.0          W        WSW          19.0
# 2008-12-04          NE           24.0         SE          E          11.0
# 2008-12-05           W           41.0        ENE         NW           7.0
# 2008-12-06         WNW           56.0          W          W          19.0
# 2008-12-07           W           50.0         SW          W          20.0
# 2008-12-08           W           35.0        SSE          W           6.0
# 2008-12-09         NNW           80.0         SE         NW           7.0
# 2008-12-10           W           28.0          S        SSE          15.0
# 2008-12-11           N           30.0        SSE        ESE          17.0
# 2008-12-12         NNE           31.0         NE        ENE          15.0
# 2008-12-13           W           61.0        NNW        NNW          28.0
# 2008-12-14          SW           44.0          W        SSW          24.0
# 2008-12-15         NaN            NaN          S        WNW           4.0
#
#             WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  \
# Date
# 2008-12-01          24.0         71.0         22.0       1007.7       1007.1
# 2008-12-02          22.0         44.0         25.0       1010.6       1007.8
# 2008-12-03          26.0         38.0         30.0       1007.6       1008.7
# 2008-12-04           9.0         45.0         16.0       1017.6       1012.8
# 2008-12-05          20.0         82.0         33.0       1010.8       1006.0
# 2008-12-06          24.0         55.0         23.0       1009.2       1005.4
# 2008-12-07          24.0         49.0         19.0       1009.6       1008.2
# 2008-12-08          17.0         48.0         19.0       1013.4       1010.1
# 2008-12-09          28.0         42.0          9.0       1008.9       1003.6
# 2008-12-10          11.0         58.0         27.0       1007.0       1005.7
# 2008-12-11           6.0         48.0         22.0       1011.8       1008.7
# 2008-12-12          13.0         89.0         91.0       1010.5       1004.2
# 2008-12-13          28.0         76.0         93.0        994.3        993.0
# 2008-12-14          20.0         65.0         43.0       1001.2       1001.8
# 2008-12-15          30.0         57.0         32.0       1009.7       1008.7
#
#             Cloud9am  Cloud3pm  Temp9am  Temp3pm RainToday RainTomorrow
# Date
# 2008-12-01       8.0       NaN     16.9     21.8        No           No
# 2008-12-02       NaN       NaN     17.2     24.3        No           No
# 2008-12-03       NaN       2.0     21.0     23.2        No           No
# 2008-12-04       NaN       NaN     18.1     26.5        No           No
# 2008-12-05       7.0       8.0     17.8     29.7        No           No
# 2008-12-06       NaN       NaN     20.6     28.9        No           No
# 2008-12-07       1.0       NaN     18.1     24.6        No           No
# 2008-12-08       NaN       NaN     16.3     25.5        No           No
# 2008-12-09       NaN       NaN     18.3     30.2        No          Yes
# 2008-12-10       NaN       NaN     20.1     28.2       Yes           No
# 2008-12-11       NaN       NaN     20.4     28.8        No          Yes
# 2008-12-12       8.0       8.0     15.9     17.0       Yes          Yes
# 2008-12-13       8.0       8.0     17.4     15.8       Yes          Yes
# 2008-12-14       NaN       7.0     15.8     19.8       Yes           No
# 2008-12-15       NaN       NaN     15.9     23.5        No          NaN

# %%
# Display count of missing values
#  isna() and isnull() are equivalent
#  NaN is considered a missing value
df2.isna().sum()
# Out:
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
# Drop all rows where WindGustSpeed is NaN
df2 = df2.dropna(subset=['WindGustDir'])

# %%
df2.shape
# Out:
# (135134, 22)

# %%
df2.isnull().sum()
# Out:
# Location             0
# MinTemp            738
# MaxTemp            562
# Rainfall          2660
# Evaporation      57516
# Sunshine         64047
# WindGustDir          0
# WindGustSpeed        0
# WindDir9am        7615
# WindDir3pm         970
# WindSpeed9am       343
# WindSpeed3pm       281
# Humidity9am       1893
# Humidity3pm       2375
# Pressure9am      10780
# Pressure3pm      10739
# Cloud9am         53582
# Cloud3pm         55642
# Temp9am           1089
# Temp3pm           1547
# RainToday         2660
# RainTomorrow      2271
# dtype: int64

# %%
df2.head(15)
# Out:
#            Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# Date
# 2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# 2008-12-06   Albury     14.6     29.7       0.2          NaN       NaN
# 2008-12-07   Albury     14.3     25.0       0.0          NaN       NaN
# 2008-12-08   Albury      7.7     26.7       0.0          NaN       NaN
# 2008-12-09   Albury      9.7     31.9       0.0          NaN       NaN
# 2008-12-10   Albury     13.1     30.1       1.4          NaN       NaN
# 2008-12-11   Albury     13.4     30.4       0.0          NaN       NaN
# 2008-12-12   Albury     15.9     21.7       2.2          NaN       NaN
# 2008-12-13   Albury     15.9     18.6      15.6          NaN       NaN
# 2008-12-14   Albury     12.6     21.0       3.6          NaN       NaN
# 2008-12-16   Albury      9.8     27.7       NaN          NaN       NaN
#
#            WindGustDir  WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  \
# Date
# 2008-12-01           W           44.0          W        WNW          20.0
# 2008-12-02         WNW           44.0        NNW        WSW           4.0
# 2008-12-03         WSW           46.0          W        WSW          19.0
# 2008-12-04          NE           24.0         SE          E          11.0
# 2008-12-05           W           41.0        ENE         NW           7.0
# 2008-12-06         WNW           56.0          W          W          19.0
# 2008-12-07           W           50.0         SW          W          20.0
# 2008-12-08           W           35.0        SSE          W           6.0
# 2008-12-09         NNW           80.0         SE         NW           7.0
# 2008-12-10           W           28.0          S        SSE          15.0
# 2008-12-11           N           30.0        SSE        ESE          17.0
# 2008-12-12         NNE           31.0         NE        ENE          15.0
# 2008-12-13           W           61.0        NNW        NNW          28.0
# 2008-12-14          SW           44.0          W        SSW          24.0
# 2008-12-16         WNW           50.0        NaN        WNW           NaN
#
#             WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  \
# Date
# 2008-12-01          24.0         71.0         22.0       1007.7       1007.1
# 2008-12-02          22.0         44.0         25.0       1010.6       1007.8
# 2008-12-03          26.0         38.0         30.0       1007.6       1008.7
# 2008-12-04           9.0         45.0         16.0       1017.6       1012.8
# 2008-12-05          20.0         82.0         33.0       1010.8       1006.0
# 2008-12-06          24.0         55.0         23.0       1009.2       1005.4
# 2008-12-07          24.0         49.0         19.0       1009.6       1008.2
# 2008-12-08          17.0         48.0         19.0       1013.4       1010.1
# 2008-12-09          28.0         42.0          9.0       1008.9       1003.6
# 2008-12-10          11.0         58.0         27.0       1007.0       1005.7
# 2008-12-11           6.0         48.0         22.0       1011.8       1008.7
# 2008-12-12          13.0         89.0         91.0       1010.5       1004.2
# 2008-12-13          28.0         76.0         93.0        994.3        993.0
# 2008-12-14          20.0         65.0         43.0       1001.2       1001.8
# 2008-12-16          22.0         50.0         28.0       1013.4       1010.3
#
#             Cloud9am  Cloud3pm  Temp9am  Temp3pm RainToday RainTomorrow
# Date
# 2008-12-01       8.0       NaN     16.9     21.8        No           No
# 2008-12-02       NaN       NaN     17.2     24.3        No           No
# 2008-12-03       NaN       2.0     21.0     23.2        No           No
# 2008-12-04       NaN       NaN     18.1     26.5        No           No
# 2008-12-05       7.0       8.0     17.8     29.7        No           No
# 2008-12-06       NaN       NaN     20.6     28.9        No           No
# 2008-12-07       1.0       NaN     18.1     24.6        No           No
# 2008-12-08       NaN       NaN     16.3     25.5        No           No
# 2008-12-09       NaN       NaN     18.3     30.2        No          Yes
# 2008-12-10       NaN       NaN     20.1     28.2       Yes           No
# 2008-12-11       NaN       NaN     20.4     28.8        No          Yes
# 2008-12-12       8.0       8.0     15.9     17.0       Yes          Yes
# 2008-12-13       8.0       8.0     17.4     15.8       Yes          Yes
# 2008-12-14       NaN       7.0     15.8     19.8       Yes           No
# 2008-12-16       0.0       NaN     17.3     26.2       NaN           No

# %%
df2.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  134396.000000  134572.000000  132474.000000  77618.000000
# mean       12.144036      23.287516       2.329065      5.514989
# std         6.462347       7.201843       8.402218      4.220401
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.500000      17.900000       0.000000      2.600000
# 50%        11.900000      22.800000       0.000000      4.800000
# 75%        16.800000      28.400000       0.600000      7.400000
# max        33.900000      48.100000     367.600000     86.200000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  71087.000000  135134.000000  134791.000000  134853.000000
# mean       7.648307      40.035106      14.228932      18.771863
# std        3.787404      13.607080       8.792967       8.682182
# min        0.000000       6.000000       0.000000       0.000000
# 25%        4.900000      31.000000       7.000000      13.000000
# 50%        8.500000      39.000000      13.000000      19.000000
# 75%       10.700000      48.000000      20.000000      24.000000
# max       14.500000     135.000000      87.000000      87.000000
#
#          Humidity9am    Humidity3pm    Pressure9am    Pressure3pm  \
# count  133241.000000  132759.000000  124354.000000  124395.000000
# mean       68.629911      51.120813    1017.628408    1015.220109
# std        19.227565      20.866908       7.100802       7.030968
# min         0.000000       0.000000     980.500000     977.100000
# 25%        57.000000      36.000000    1012.900000    1010.400000
# 50%        70.000000      51.000000    1017.600000    1015.200000
# 75%        83.000000      65.000000    1022.400000    1020.000000
# max       100.000000     100.000000    1041.000000    1039.600000
#
#            Cloud9am      Cloud3pm        Temp9am        Temp3pm
# count  81552.000000  79492.000000  134045.000000  133587.000000
# mean       4.437083      4.510139      16.985706      21.741268
# std        2.888186      2.722881       6.565138       7.007074
# min        0.000000      0.000000      -7.200000      -5.400000
# 25%        1.000000      2.000000      12.200000      16.600000
# 50%        5.000000      5.000000      16.700000      21.200000
# 75%        7.000000      7.000000      21.600000      26.600000
# max        9.000000      9.000000      40.200000      46.700000

# %%
# Display the # of unique values for each column
df2.nunique()
# Out:
# Location          47
# MinTemp          389
# MaxTemp          504
# Rainfall         653
# Evaporation      357
# Sunshine         145
# WindGustDir       16
# WindGustSpeed     67
# WindDir9am        16
# WindDir3pm        16
# WindSpeed9am      40
# WindSpeed3pm      42
# Humidity9am      101
# Humidity3pm      101
# Pressure9am      545
# Pressure3pm      543
# Cloud9am          10
# Cloud3pm          10
# Temp9am          440
# Temp3pm          501
# RainToday          2
# RainTomorrow       2
# dtype: int64

# %%
# Display a column's unique values
df2.Location.unique()
# Out:
# array(['Albury', 'BadgerysCreek', 'Cobar', 'CoffsHarbour', 'Moree',
#        'NorahHead', 'NorfolkIsland', 'Penrith', 'Richmond', 'Sydney',
#        'SydneyAirport', 'WaggaWagga', 'Williamtown', 'Wollongong',
#        'Canberra', 'Tuggeranong', 'MountGinini', 'Ballarat', 'Bendigo',
#        'Sale', 'MelbourneAirport', 'Melbourne', 'Mildura', 'Nhil',
#        'Portland', 'Watsonia', 'Dartmoor', 'Brisbane', 'Cairns',
#        'GoldCoast', 'Townsville', 'Adelaide', 'MountGambier', 'Nuriootpa',
#        'Woomera', 'Witchcliffe', 'PearceRAAF', 'PerthAirport', 'Perth',
#        'SalmonGums', 'Walpole', 'Hobart', 'Launceston', 'AliceSprings',
#        'Darwin', 'Katherine', 'Uluru'], dtype=object)

# %%
# Display the counts for each of the unique values in column 'Location' in descending count order
df2.Location.value_counts()
# Out:
# Perth               3188
# Melbourne           3179
# Hobart              3170
# Adelaide            3167
# Brisbane            3152
# Darwin              3147
# Canberra            3097
# Cairns              3021
# Townsville          3017
# Ballarat            3009
# Albury              3008
# Launceston          3006
# Mildura             3004
# Bendigo             2999
# Tuggeranong         2997
# MelbourneAirport    2994
# Wollongong          2992
# AliceSprings        2989
# MountGambier        2987
# WaggaWagga          2981
# Witchcliffe         2975
# Portland            2974
# Penrith             2974
# Watsonia            2972
# Woomera             2970
# Cobar               2967
# NorfolkIsland       2964
# PerthAirport        2963
# Nuriootpa           2960
# SydneyAirport       2958
# Richmond            2952
# NorahHead           2950
# Dartmoor            2940
# BadgerysCreek       2933
# Moree               2931
# GoldCoast           2920
# SalmonGums          2917
# Walpole             2888
# Williamtown         2873
# Sale                2868
# PearceRAAF          2864
# MountGinini         2721
# CoffsHarbour        2650
# Sydney              2306
# Nhil                1567
# Katherine           1549
# Uluru               1524
# Name: Location, dtype: int64

# %%
# Display a Pandas boxplot for columns MinTemp and MaxTemp
df2.boxplot(['MinTemp','MaxTemp'])
# Out:
# <Axes: >

# %%
# Display a Seaborn boxplot of temperature ranges for selected cities
sns.set(rc={'figure.figsize':(10,6)})
sns.boxplot(x='Location', y='MaxTemp', \
            data=df2[df2['Location'].isin(['Sydney','Canberra','Brisbane','Adelaide','Melbourne','Perth'])])
# Out:
# <Axes: xlabel='Location', ylabel='MaxTemp'>
